# %%
import pandas as pd

# series
series = pd.Series([2, 8, -2, 10])
print(type(series))
print(series)

staff = {
  "name" : "Leo",
  "age" : 23
}

df = pd.DataFrame(staff, index=[0])
print(df)

team = {
  "names" : ["Leo", "Tom", "Peter"],
  "ages" : [23, 10, 18]
}

df_team = pd.DataFrame(team)
print(df_team)

print(df_team["names"])
print(type(df_team["names"]))

df_team['gender'] = pd.Series(['M', 'M', 'M'])
print(df_team)
# Out:
# <class 'pandas.Series'>
# 0     2
# 1     8
# 2    -2
# 3    10
# dtype: int64
#   name  age
# 0  Leo   23
#    names  ages
# 0    Leo    23
# 1    Tom    10
# 2  Peter    18
# 0      Leo
# 1      Tom
# 2    Peter
# Name: names, dtype: str
# <class 'pandas.Series'>
#    names  ages gender
# 0    Leo    23      M
# 1    Tom    10      M
# 2  Peter    18      M

# %%
df_team_2 = df_team.loc[df_team['ages'] > 15]
print(df_team_2)
print(type(df_team_2)) # Dataframe

df_team_3 = df_team.loc[df_team["names"].str.len() > 3]
print(df_team_3)

# & (and), | (or)
df_team_4 = df_team.loc[(df_team["ages"] > 5) | (df_team["names"].str.len() > 3)]
print(df_team_4)

df_team_5 = df_team.loc[df_team["names"].str.contains("o")]
print(df_team_5)
# Out:
#    names  ages gender
# 0    Leo    23      M
# 2  Peter    18      M
# <class 'pandas.DataFrame'>
#    names  ages gender
# 2  Peter    18      M
#    names  ages gender
# 0    Leo    23      M
# 1    Tom    10      M
# 2  Peter    18      M
#   names  ages gender
# 0   Leo    23      M
# 1   Tom    10      M

# %%
print(df_team.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   names   3 non-null      str
#  1   ages    3 non-null      int64
#  2   gender  3 non-null      str
# dtypes: int64(1), str(2)
# memory usage: 204.0 bytes
# None

# %%
print(df_team.describe())
# Out:
#             ages
# count   3.000000
# mean   17.000000
# std     6.557439
# min    10.000000
# 25%    14.000000
# 50%    18.000000
# 75%    20.500000
# max    23.000000

# %%
print(df_team.head())
# Out:
#    names  ages gender
# 0    Leo    23      M
# 1    Tom    10      M
# 2  Peter    18      M

# %%
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'

df = pd.read_csv(url)
print(type(df))
print(df.head())
# Out:
# <class 'pandas.DataFrame'>
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
# Sex = Male, Name contains "Allen"
print(df[(df['Sex'] == 'male') & (df['Name'].str.contains('Allen'))])
# Out:
#    PassengerId  Survived  Pclass                      Name   Sex   Age  SibSp  \
# 4            5         0       3  Allen, Mr. William Henry  male  35.0      0
#
#    Parch  Ticket  Fare Cabin Embarked
# 4      0  373450  8.05   NaN        S

# %%
print(df['Age'].isnull().any())

# Drop data with null age
df_drop_na_age = df.dropna(subset=["Age"])
print(df_drop_na_age['Age'].isnull().any())

print(len(df))
print(len(df_drop_na_age))
# Out:
# True
# False
# 891
# 714

# %%
# Refill
df_for_refill = df.copy()
df_for_refill['Age'] = df_for_refill['Age'].fillna("N/A")
print(len(df_for_refill))
print(df_for_refill['Age'].isnull().any())
# Out:
# 891
# False

# %%
# loc -> where
# group by

print(df["Age"].mean())
print(df["Age"].min())
print(df["Age"].max())

# Find mean age for each 'Survived' group
df_result = df.groupby('Survived')['Age'].mean()
print(df_result)
print(type(df_result))
# Out:
# 29.69911764705882
# 0.42
# 80.0
# Survived
# 0    30.626179
# 1    28.343690
# Name: Age, dtype: float64
# <class 'pandas.Series'>
