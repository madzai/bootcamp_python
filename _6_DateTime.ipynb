# %%
from datetime import datetime, date, timedelta

print(datetime.now())
print(date.today())

birthday = date(2020, 11, 20)
print(birthday)
print(type(birthday))

birthday += timedelta(days=10)
print(birthday)
# Out:
# 2026-02-06 11:37:29.977372
# 2026-02-06
# 2020-11-20
# <class 'datetime.date'>
# 2020-11-30

# %%
from dateutil.relativedelta import relativedelta

probation_end_date = date.today() + relativedelta(months=3)
print(probation_end_date)

print(date.today() + relativedelta(years = 2, months=1))
print(date.today() + relativedelta(days = 40))
# Out:
# 2026-05-06
# 2028-03-06
# 2026-03-18

# %%
formatted_date = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(formatted_date)
print(type(formatted_date))

str_datetime = "2025/12/31 23:59:59"
today = datetime.strptime(str_datetime, "%Y/%m/%d %H:%M:%S")
print(today)
print(type(today))
# Out:
# 2026-02-06 11:37:10
# <class 'str'>
# 2025-12-31 23:59:59
# <class 'datetime.datetime'>
