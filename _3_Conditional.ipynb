# %%
x = 10
if (x > 9):
  print('hello')
else:
  print('goodbye')
# Out:
# hello

# %%
score = 91
# >= 90 (A)
# >= 80 (B)
# (F)
if (score >= 90):
  grade = 'A'
elif (score >= 80):
  grade = 'B'
else:
  grade = 'F'

print(f'Grade=' + grade)
print(f'Grade={grade}')
# Out:
# Grade=A
# Grade=A

# %%
x = 10

# Java: || &&
# Python: or and

if (x > 4 and x < 12):
  print('hello')

if (x > 4 or x < 9):
  print('goodbye')

age = 66
# Java age >= 65 ? 2 : 10
fee = 2 if age >= 65 else 10
print(fee)
# Out:
# hello
# goodbye
# 2

# %%
# Java: equals
# Python: ==
input_password = 'admin1234'
actual_password = 'admin1234'
if (input_password == actual_password):
  print('Login success')
else:
  print('Login failure')

print(input_password != actual_password) # False
# Out:
# Login success
# False

# %%
# Number Math Operation
# odd
number = 3
if (number % 2 == 1):
  print('Odd')
else:
  print('Even')
# Out:
# Odd

# %%
# Python >= 3.10
# Java switch
# Python match

weekday = 'Thursday'
match weekday:
  case 'Monday':
    print('Mon')
  case 'Tuesday':
    print('Tue')
  case 'Wednesday':
    print('Wed')
  case 'Thursday':
    print('Thu')
  case 'Friday':
    print('Fri')
  case _:
    print('Default')
# Out:
# Thu
