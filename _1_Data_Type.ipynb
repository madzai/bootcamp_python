# %%
3 + 2
# Out:
# 5

# %%
3 + 2
11 + 9
# Out:
# 20

# %%
print(3 + 2)
print(11 + 9)
# Out:
# 5
# 20

# %%
x = 3
print(x)
print(type(x))

x = 3.3
print(x)
print(type(x))

x = 'hello'
print(x)
print(type(x))
# Out:
# 3
# <class 'int'>
# 3.3
# <class 'float'>
# hello
# <class 'str'>

# %%
# int, str, float, bool
y = True
y = False
print(y)
print(type(y))
# Out:
# False
# <class 'bool'>

# %%
# str
s = 'hello'
print(s * 3)

s += 'world'
print(s)

s = s + '!!!'
print(s)

first_name = 'Vincent'
last_name = 'Chan'
print(first_name + ' ' + last_name)
print(f'He is {first_name} {last_name}')
# Out:
# hellohellohello
# helloworld
# helloworld!!!
# Vincent Chan
# He is Vincent Chan

# %%
result = 10 / 3
print(result)

print(0.1 + 0.2) # 0.30000000000000004
print(round(0.1 + 0.2, 1))

# print(10 / 0) # programming error
# Out:
# 3.3333333333333335
# 0.30000000000000004
# 0.3
